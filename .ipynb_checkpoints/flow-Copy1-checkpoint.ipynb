# %%
import jax
jax.config.update('jax_enable_x64',True)

# %%
import numpyro
from NSF import NeuralSpline1D
from flow import Normal,Flow,transform,Serial
from SkewNormalPlus import SkewNormalPlus as snp

# %%
from jax import random
import jax_cosmo as jc
from jax_cosmo import Cosmology, background
import numpy as onp
import jax.numpy as np
from jax import grad, jit, vmap, value_and_grad
from jax.scipy.stats import norm

# %%
@jit
def make_training_set(key,z_s,M0=-19.5,sigma_int=0.1,h=0.7324,Om0=0.28,w=-1,mu_cut=21,sigma_cut=0.01):




    cosmo_jax = Cosmology(Omega_c=Om0, h=h, w0=w, Omega_b=0, n_s= 0.96, sigma8=200000, Omega_k=0, wa=0)

    n_sne=len(z_s)

    d_s=background.transverse_comoving_distance(cosmo_jax, 1/(1+z_s))

    mu_s=5*np.log10((1+z_s)/h*d_s*1e6/10)

    m0_s=M0+mu_s

    m_s=random.normal(key, (len(m0_s),))*sigma_int+m0_s

    key, _ = random.split(key)

    p_s=norm.cdf(-m_s, loc=-mu_cut, scale=sigma_cut)

    sel_s=random.bernoulli(key, p=p_s)

    return m0_s,m_s,sel_s



def minmax_fit_and_scale(X):
  max= np.max(X,axis=0)
  min = np.min(X,axis=0)
  X_std = (X - min) / (max-min)
  return X_std,min,max


def minmax_scale(X,min,max):
  return (X - min) / (max - min)

# %%
from jax.example_libraries import stax, optimizers

from jax.example_libraries.stax import (Dense, Tanh, Flatten, Relu, LogSoftmax, Softmax, Exp,Sigmoid,Softplus,LeakyRelu)
'''
def network(rng,conditional_dim,out_dim, hidden_dim):
    init_fun,apply_fun=stax.serial(stax.Dense(hidden_dim),  Relu, stax.Dense(1024),Relu,stax.Dense(hidden_dim), Relu, stax.Dense(out_dim),)
    _, params = init_fun(rng, (conditional_dim,))

    return params,apply_fun
'''
def network(rng,conditional_dim,out_dim, hidden_dim):
    init_fun,apply_fun=stax.serial(stax.Dense(hidden_dim), Tanh, stax.Dense(1024),Tanh,stax.Dense(hidden_dim), Tanh, stax.Dense(out_dim),)
    _, params = init_fun(rng, (conditional_dim,))
    return params,apply_fun

rng, flow_rng = random.split(random.PRNGKey(43))

init_fun = Flow(Serial(*(NeuralSpline1D(network,hidden_dim=128,K=5,B=3),)*2),prior=Normal())

params, log_pdf, sample = init_fun(flow_rng,2 )

# %%
opt_init, opt_update, get_params = optimizers.adam(step_size=1e-4)
opt_state = opt_init(params)

# %%
def loss_fn(params, inputs):
    return -log_pdf(params, inputs).mean()

@jit
def step(i, opt_state, inputs):
    params = get_params(opt_state)

    loss,gradients = value_and_grad(loss_fn)(params,inputs)
    return loss, opt_update(i, gradients, opt_state)

def minmax_unscale(X,min,max):
  return X * (max - min) + min

# %%
from tqdm.notebook import trange
import itertools
import numpy.random as npr
itercount = itertools.count()
sample_batch=1000
batch_size=1000
import logging
itercount = itertools.count()
from IPython.display import clear_output




for epoch in range(1000):
    

  X = np.empty((0,3))
 
  for s_epoch in range(20):
    
      permute_rng, rng = random.split(rng)  
      sigma_int =   random.uniform(rng,(1,))

  
      sigma_cut=0.01
      mu_cut= 21

      permute_rng, rng = random.split(rng)


      mu=random.uniform(rng,(10,))*(21+2*sigma_int[0]-20.5) + 20.5


      s = snp(m_int=mu,sigma_int=sigma_int,m_cut=mu_cut,sigma_cut=sigma_cut)

      permute_rng, rng = random.split(rng)
      

      samps=s.sample(rng,(5,10))
        
      permute_rng, rng = random.split(rng)



      theta = np.column_stack((np.repeat(mu,5).T.reshape(50,1),np.repeat(sigma_int,50).reshape(50,1)))
    

        
      X_ = np.column_stack((samps.T.reshape(50,1),theta))
    
      X = np.append(X,X_,axis=0)
        
  if epoch == 0:
      X,min,max=minmax_fit_and_scale(X)

    
  else:
      X  = minmax_scale(X,min,max)



  print(X)
  loss,opt_state = step(next(itercount), opt_state, X)
  params = get_params(opt_state)
  print('epoch: ',epoch,' loss: ', loss)

      
  
  if epoch % 100 == 0 :
        from matplotlib import pyplot as plt
        c=['red','green','blue','yellow','pink']
        mm = np.array([20.7,20.8,20.9,21,21.1])
        bins=np.linspace(20.3,21.1,100)
        no_samps = 50000


        plt.figure(figsize=(12,6))



        for i,m in enumerate(mm):
            

            samp=sample(rng, params,minmax_scale(np.column_stack((np.repeat(np.array([m]),no_samps).reshape(no_samps,1),np.array([0.1]*no_samps).reshape(no_samps,1))),min[1:],max[1:]),no_samps)
            samp = minmax_unscale(samp[:,0],min[0],max[0])

            plt.hist(samp,density=True,bins=bins,color=c[i],histtype='step',label='$m_0=$'+str(m)+',$\sigma_{int}=0.1$,$m_{cut}=$'+str(mu_cut)+',$\sigma_{cut}=$'+str(sigma_cut))
            s=snp(np.array([m]),np.array([0.1]),21,0.01)
            plt.plot(bins,np.exp(s.log_prob(bins)),color=c[i])
    

    
        plt.legend(loc='center left',frameon=False,fontsize=12)
        plt.xlabel('$\hat{m}_s$',fontsize=11)
        plt.ylabel('$p(\hat{m}_s|m_0,\sigma_{int},m_{cut},\sigma_{cut})$',fontsize=12)
        plt.title('Normalising Flow',fontsize=12)

        plt.show()
# Out:
# [[0.88272576 0.02217965 0.98478856]
#  [0.33079777 0.02217965 0.98478856]
#  [0.63940252 0.02217965 0.98478856]
#  ...
#  [0.77805149 0.0945782  0.1577597 ]
#  [0.87377066 0.0945782  0.1577597 ]
#  [0.70578698 0.0945782  0.1577597 ]]
# epoch:  0  loss:  1.422421914772674
# [[0.9654678  0.66089198 0.02222396]
#  [0.98105395 0.66089198 0.02222396]
#  [0.97815248 0.66089198 0.02222396]
#  ...
#  [0.73742156 0.09099497 0.53971057]
#  [0.84778429 0.09099497 0.53971057]
#  [0.89203321 0.09099497 0.53971057]]
# epoch:  1  loss:  inf
# [[ 0.85459029  0.12347075 -0.02946035]
#  [ 0.83822797  0.12347075 -0.02946035]
#  [ 0.8426856   0.12347075 -0.02946035]
#  ...
#  [ 0.95844066  0.5963797   0.13884026]
#  [ 0.94089281  0.5963797   0.13884026]
#  [ 0.97092936  0.5963797   0.13884026]]
# epoch:  2  loss:  nan
# [[0.8287084  0.5963101  0.16060728]
#  [0.87403027 0.5963101  0.16060728]
#  [0.97253792 0.5963101  0.16060728]
#  ...
#  [0.89323268 0.22623006 0.01281133]
#  [0.83573606 0.22623006 0.01281133]
#  [0.82335564 0.22623006 0.01281133]]
# epoch:  3  loss:  nan
# [[0.91893033 0.9510227  0.33678804]
#  [0.93260613 0.9510227  0.33678804]
#  [0.97280445 0.9510227  0.33678804]
#  ...
#  [0.81649882 0.57816879 0.30603221]
#  [0.9872564  0.57816879 0.30603221]
#  [0.78771375 0.57816879 0.30603221]]
# epoch:  4  loss:  nan
# [[0.79220275 0.89034221 0.96736445]
#  [0.55935434 0.89034221 0.96736445]
#  [0.80375477 0.89034221 0.96736445]
#  ...
#  [0.95353907 0.64185493 0.37412739]
#  [0.95833658 0.64185493 0.37412739]
#  [0.95005709 0.64185493 0.37412739]]
# epoch:  5  loss:  nan
# [[0.73829026 0.64491882 0.33559612]
#  [0.90982861 0.64491882 0.33559612]
#  [0.72684649 0.64491882 0.33559612]
#  ...
#  [0.42837934 0.53329306 0.81721665]
#  [0.89797273 0.53329306 0.81721665]
#  [0.96565426 0.53329306 0.81721665]]
# epoch:  6  loss:  nan
# [[0.98080997 0.60250264 1.02141806]
#  [0.9324321  0.60250264 1.02141806]
#  [0.51010092 0.60250264 1.02141806]
#  ...
#  [0.76395218 0.44352294 0.98838124]
#  [0.9686664  0.44352294 0.98838124]
#  [0.74001665 0.44352294 0.98838124]]
# epoch:  7  loss:  nan
# [[0.94591761 0.94838419 0.74348146]
#  [0.96069225 0.94838419 0.74348146]
#  [0.9414018  0.94838419 0.74348146]
#  ...
#  [0.65521047 0.21394441 0.74982233]
#  [0.77226761 0.21394441 0.74982233]
#  [0.90527973 0.21394441 0.74982233]]
# epoch:  8  loss:  nan
# [[0.90516043 0.42140002 0.59294549]
#  [0.70539272 0.42140002 0.59294549]
#  [0.36528139 0.42140002 0.59294549]
#  ...
#  [0.81453163 0.32978055 0.23798756]
#  [0.93271165 0.32978055 0.23798756]
#  [0.95374638 0.32978055 0.23798756]]
# epoch:  9  loss:  nan
# [[0.91576952 0.98539809 0.38010103]
#  [0.88671238 0.98539809 0.38010103]
#  [0.89503821 0.98539809 0.38010103]
#  ...
#  [0.95963063 0.90832215 0.64150758]
#  [0.88586197 0.90832215 0.64150758]
#  [0.8057551  0.90832215 0.64150758]]
# epoch:  10  loss:  nan
# [[0.76867837 0.79648707 0.9873419 ]
#  [0.67251679 0.79648707 0.9873419 ]
#  [0.61337427 0.79648707 0.9873419 ]
#  ...
#  [0.96921651 0.85231521 0.99570607]
#  [0.89113369 0.85231521 0.99570607]
#  [0.86650402 0.85231521 0.99570607]]
# epoch:  11  loss:  nan
# [[0.42687135 0.76984917 0.69954616]
#  [0.86749173 0.76984917 0.69954616]
#  [0.86391824 0.76984917 0.69954616]
#  ...
#  [0.76201728 0.18016966 0.77901114]
#  [0.75630978 0.18016966 0.77901114]
#  [0.72624941 0.18016966 0.77901114]]
# epoch:  12  loss:  nan
# [[0.90027858 0.906575   0.81186648]
#  [0.87830034 0.906575   0.81186648]
#  [0.9051408  0.906575   0.81186648]
#  ...
#  [0.66809675 0.39725122 0.48781182]
#  [0.87571859 0.39725122 0.48781182]
#  [0.88254746 0.39725122 0.48781182]]
# epoch:  13  loss:  nan
# [[0.82953861 0.76225128 0.49073547]
#  [0.84008824 0.76225128 0.49073547]
#  [0.87900889 0.76225128 0.49073547]
#  ...
#  [0.77804087 0.26418601 0.42412001]
#  [0.96679449 0.26418601 0.42412001]
#  [0.56886082 0.26418601 0.42412001]]
# epoch:  14  loss:  nan
# [[0.75373446 0.94635701 0.66192031]
#  [0.87883882 0.94635701 0.66192031]
#  [0.6765098  0.94635701 0.66192031]
#  ...
#  [0.36835177 0.41397966 0.75319123]
#  [0.90130512 0.41397966 0.75319123]
#  [0.43316988 0.41397966 0.75319123]]
# epoch:  15  loss:  nan
# [[0.53888007 0.03339854 0.675948  ]
#  [0.6589166  0.03339854 0.675948  ]
#  [0.14613783 0.03339854 0.675948  ]
#  ...
#  [0.90996919 0.71898387 0.30419475]
#  [0.85960215 0.71898387 0.30419475]
#  [0.74228603 0.71898387 0.30419475]]
# epoch:  16  loss:  nan
# [[0.65554978 0.71573325 0.78772372]
#  [0.91320836 0.71573325 0.78772372]
#  [0.81832709 0.71573325 0.78772372]
#  ...
#  [0.95145909 0.64565544 0.36213219]
#  [0.97232744 0.64565544 0.36213219]
#  [0.82886315 0.64565544 0.36213219]]
# epoch:  17  loss:  nan
# [[0.86798137 0.78975256 0.98918196]
#  [0.72192936 0.78975256 0.98918196]
#  [0.91094356 0.78975256 0.98918196]
#  ...
#  [0.77729965 0.27071882 1.00633346]
#  [0.67789601 0.27071882 1.00633346]
#  [0.08818249 0.27071882 1.00633346]]
# epoch:  18  loss:  nan
# [[0.97747629 0.91817577 0.4284242 ]
#  [0.98009985 0.91817577 0.4284242 ]
#  [0.94317574 0.91817577 0.4284242 ]
#  ...
#  [0.85280219 0.90551915 0.41384518]
#  [0.96106312 0.90551915 0.41384518]
#  [0.96383665 0.90551915 0.41384518]]
# epoch:  19  loss:  nan
# [[0.90460324 0.64419189 0.16565574]
#  [0.99537265 0.64419189 0.16565574]
#  [0.94109653 0.64419189 0.16565574]
#  ...
#  [0.92630065 0.03971146 0.26527988]
#  [0.87048036 0.03971146 0.26527988]
#  [0.80303579 0.03971146 0.26527988]]
# epoch:  20  loss:  nan
# [[0.852453   0.09417557 0.01866836]
#  [0.84905991 0.09417557 0.01866836]
#  [0.88946909 0.09417557 0.01866836]
#  ...
#  [0.94754699 0.18734743 0.20047253]
#  [0.71548    0.18734743 0.20047253]
#  [0.87073192 0.18734743 0.20047253]]
# epoch:  21  loss:  nan
# [[0.81158861 0.12645455 0.98474536]
#  [0.54497264 0.12645455 0.98474536]
#  [0.97881812 0.12645455 0.98474536]
#  ...
#  [0.94322609 0.52313125 0.65140211]
#  [0.94863815 0.52313125 0.65140211]
#  [0.86272095 0.52313125 0.65140211]]
# epoch:  22  loss:  nan
# [[0.96601619 0.91820213 0.33346411]
#  [0.98366014 0.91820213 0.33346411]
#  [0.86094674 0.91820213 0.33346411]
#  ...
#  [0.73816491 0.00557857 0.38090777]
#  [0.73996113 0.00557857 0.38090777]
#  [0.66249938 0.00557857 0.38090777]]
# epoch:  23  loss:  nan
# [[0.12878796 0.11150243 0.93737999]
#  [0.65974329 0.11150243 0.93737999]
#  [0.60639294 0.11150243 0.93737999]
#  ...
#  [0.99209629 0.7753367  0.35265887]
#  [0.74938877 0.7753367  0.35265887]
#  [0.9350817  0.7753367  0.35265887]]
# epoch:  24  loss:  nan
# [[ 0.93784042  0.35643306 -0.02220915]
#  [ 0.9181136   0.35643306 -0.02220915]
#  [ 0.94171267  0.35643306 -0.02220915]
#  ...
#  [ 0.97851964  0.46300923  0.21729026]
#  [ 0.77254353  0.46300923  0.21729026]
#  [ 0.9294217   0.46300923  0.21729026]]
# epoch:  25  loss:  nan
# [[0.56578352 0.91599114 0.96026003]
#  [0.50918415 0.91599114 0.96026003]
#  [0.81400453 0.91599114 0.96026003]
#  ...
#  [0.75933032 0.91248217 0.51461267]
#  [0.80255348 0.91248217 0.51461267]
#  [0.60495062 0.91248217 0.51461267]]
# epoch:  26  loss:  nan
# [[ 0.95672726  0.1380165   0.15476899]
#  [ 0.81622325  0.1380165   0.15476899]
#  [ 0.79155893  0.1380165   0.15476899]
#  ...
#  [ 0.4708096  -0.0041422   0.85118619]
#  [ 0.13256316 -0.0041422   0.85118619]
#  [ 0.48842988 -0.0041422   0.85118619]]
# epoch:  27  loss:  nan
# [[0.98012318 0.58639978 0.42754374]
#  [0.71200278 0.58639978 0.42754374]
#  [0.73667255 0.58639978 0.42754374]
#  ...
#  [0.97584954 0.94608891 0.09308809]
#  [0.97436636 0.94608891 0.09308809]
#  [0.93136712 0.94608891 0.09308809]]
# epoch:  28  loss:  nan
# [[0.90720654 0.24449814 0.84730868]
#  [0.57316667 0.24449814 0.84730868]
#  [0.88231993 0.24449814 0.84730868]
#  ...
#  [0.88557707 0.34943251 0.99538231]
#  [0.71572063 0.34943251 0.99538231]
#  [0.71628743 0.34943251 0.99538231]]
# epoch:  29  loss:  nan
# [[0.90103126 0.88567706 0.23282373]
#  [0.88469897 0.88567706 0.23282373]
#  [0.94257424 0.88567706 0.23282373]
#  ...
#  [0.56559337 0.09162129 0.78349944]
#  [0.612044   0.09162129 0.78349944]
#  [0.49672133 0.09162129 0.78349944]]
# epoch:  30  loss:  nan
# [[ 0.92676598 -0.00483848  0.31846111]
#  [ 0.96312817 -0.00483848  0.31846111]
#  [ 0.79980568 -0.00483848  0.31846111]
#  ...
#  [ 0.98383523  0.53251222  0.78369993]
#  [ 0.7809316   0.53251222  0.78369993]
#  [ 0.82278636  0.53251222  0.78369993]]
# epoch:  31  loss:  nan
# [[0.99026738 0.69024019 0.09873219]
#  [0.97483043 0.69024019 0.09873219]
#  [0.93671516 0.69024019 0.09873219]
#  ...
#  [0.80488449 0.60541355 0.74126822]
#  [0.41503804 0.60541355 0.74126822]
#  [0.83287098 0.60541355 0.74126822]]
# epoch:  32  loss:  nan
# [[0.98163407 0.65659767 0.14675736]
#  [0.86345398 0.65659767 0.14675736]
#  [0.93687937 0.65659767 0.14675736]
#  ...
#  [0.99408928 0.57087642 0.30227918]
#  [0.75179177 0.57087642 0.30227918]
#  [0.82454486 0.57087642 0.30227918]]
# epoch:  33  loss:  nan
# [[0.02476512 0.73183228 0.97718117]
#  [0.71202532 0.73183228 0.97718117]
#  [0.96683303 0.73183228 0.97718117]
#  ...
#  [0.65161006 0.1996449  0.75941807]
#  [0.73250803 0.1996449  0.75941807]
#  [0.52819819 0.1996449  0.75941807]]
# epoch:  34  loss:  nan
# [[0.72212925 0.87646997 0.79916879]
#  [0.73012764 0.87646997 0.79916879]
#  [0.56230949 0.87646997 0.79916879]
#  ...
#  [0.96441499 0.41298815 0.03416511]
#  [0.94513637 0.41298815 0.03416511]
#  [0.95023355 0.41298815 0.03416511]]
# epoch:  35  loss:  nan
# [[0.93598661 0.8805555  0.30763738]
#  [0.91735028 0.8805555  0.30763738]
#  [0.9093432  0.8805555  0.30763738]
#  ...
#  [0.76677725 0.37539053 0.69864513]
#  [0.41308781 0.37539053 0.69864513]
#  [0.46235717 0.37539053 0.69864513]]
# epoch:  36  loss:  nan
# [[0.92638727 0.60228179 0.16358456]
#  [0.97969493 0.60228179 0.16358456]
#  [0.97587176 0.60228179 0.16358456]
#  ...
#  [0.63610631 0.11187368 0.97676143]
#  [0.34938743 0.11187368 0.97676143]
#  [0.6944288  0.11187368 0.97676143]]
# epoch:  37  loss:  nan
# [[0.87657585 0.47002434 0.29342567]
#  [0.93793842 0.47002434 0.29342567]
#  [0.9649798  0.47002434 0.29342567]
#  ...
#  [0.99780667 0.0426309  0.53489336]
#  [0.69822783 0.0426309  0.53489336]
#  [0.87119816 0.0426309  0.53489336]]
# epoch:  38  loss:  nan
# [[0.98702109 0.7153202  0.06859279]
#  [0.97806755 0.7153202  0.06859279]
#  [0.95191137 0.7153202  0.06859279]
#  ...
#  [0.60491217 0.93856882 0.89177604]
#  [0.53985136 0.93856882 0.89177604]
#  [0.90390457 0.93856882 0.89177604]]
# epoch:  39  loss:  nan
# [[0.80259635 0.17650655 0.00281207]
#  [0.84355572 0.17650655 0.00281207]
#  [0.86494674 0.17650655 0.00281207]
#  ...
#  [0.92371485 0.46510301 0.04226074]
#  [0.94753967 0.46510301 0.04226074]
#  [0.96441795 0.46510301 0.04226074]]
# epoch:  40  loss:  nan
# [[0.84574597 0.54778574 0.673729  ]
#  [0.44287742 0.54778574 0.673729  ]
#  [0.79599787 0.54778574 0.673729  ]
#  ...
#  [0.86682064 0.70400066 0.3130679 ]
#  [0.97236127 0.70400066 0.3130679 ]
#  [0.91875737 0.70400066 0.3130679 ]]
# epoch:  41  loss:  nan
# [[ 0.91780874  0.50673135  0.60381493]
#  [ 0.96604052  0.50673135  0.60381493]
#  [ 0.88133099  0.50673135  0.60381493]
#  ...
#  [-0.83069924  0.92336817  0.02790395]
#  [-0.89316945  0.92336817  0.02790395]
#  [-0.7756009   0.92336817  0.02790395]]
# epoch:  42  loss:  nan
# [[0.83893789 0.80785477 0.87775607]
#  [0.94639381 0.80785477 0.87775607]
#  [0.65385148 0.80785477 0.87775607]
#  ...
#  [0.72651243 0.62288127 0.56456697]
#  [0.68220447 0.62288127 0.56456697]
#  [0.68492341 0.62288127 0.56456697]]
# epoch:  43  loss:  nan
# [[0.93133813 0.54170726 0.10454933]
#  [0.9829634  0.54170726 0.10454933]
#  [0.96125739 0.54170726 0.10454933]
#  ...
#  [0.96649003 0.79852502 0.56672601]
#  [0.8922512  0.79852502 0.56672601]
#  [0.93341137 0.79852502 0.56672601]]
# epoch:  44  loss:  nan
# [[0.88883215 0.16056267 0.05175982]
#  [0.86194613 0.16056267 0.05175982]
#  [0.82228403 0.16056267 0.05175982]
#  ...
#  [0.83628723 0.1316248  0.01983942]
#  [0.81635688 0.1316248  0.01983942]
#  [0.86295599 0.1316248  0.01983942]]
# epoch:  45  loss:  nan
# [[0.94914799 0.43447319 0.11967991]
#  [0.98923601 0.43447319 0.11967991]
#  [0.91085832 0.43447319 0.11967991]
#  ...
#  [0.61961306 0.31898787 0.66102718]
#  [0.81504578 0.31898787 0.66102718]
#  [0.700812   0.31898787 0.66102718]]
# epoch:  46  loss:  nan
# [[0.92130589 0.77732487 0.38723627]
#  [0.87570767 0.77732487 0.38723627]
#  [0.92648068 0.77732487 0.38723627]
#  ...
#  [0.94398241 0.76376498 0.33273624]
#  [0.93160082 0.76376498 0.33273624]
#  [0.93119032 0.76376498 0.33273624]]
# epoch:  47  loss:  nan
# [[0.94640164 0.24839014 0.04826737]
#  [0.87118396 0.24839014 0.04826737]
#  [0.90456371 0.24839014 0.04826737]
#  ...
#  [0.93399025 0.54415461 0.15205253]
#  [0.95381259 0.54415461 0.15205253]
#  [0.96238466 0.54415461 0.15205253]]
# epoch:  48  loss:  nan
# [[0.87761312 0.18886874 0.29738094]
#  [0.85574573 0.18886874 0.29738094]
#  [0.739882   0.18886874 0.29738094]
#  ...
#  [0.88102467 0.52743025 0.31594556]
#  [0.84108296 0.52743025 0.31594556]
#  [0.77492857 0.52743025 0.31594556]]
# epoch:  49  loss:  nan
# [[0.87993821 0.20586926 0.10551091]
#  [0.73471932 0.20586926 0.10551091]
#  [0.7946352  0.20586926 0.10551091]
#  ...
#  [0.93417339 0.58340148 1.01139847]
#  [0.18004826 0.58340148 1.01139847]
#  [0.69500545 0.58340148 1.01139847]]
# epoch:  50  loss:  nan
# [[0.94731306 0.23138996 0.31086962]
#  [0.92412502 0.23138996 0.31086962]
#  [0.80892329 0.23138996 0.31086962]
#  ...
#  [0.65617847 0.67346333 0.52751526]
#  [0.7420594  0.67346333 0.52751526]
#  [0.62816658 0.67346333 0.52751526]]
# epoch:  51  loss:  nan
# [[       -inf  0.84980794 -0.01406549]
#  [       -inf  0.84980794 -0.01406549]
#  [       -inf  0.84980794 -0.01406549]
#  ...
#  [ 0.96265167  0.2121911   0.59242885]
#  [ 0.25019584  0.2121911   0.59242885]
#  [ 0.98686957  0.2121911   0.59242885]]
# epoch:  52  loss:  nan
# [[0.54047643 0.83983667 0.70114403]
#  [0.92140306 0.83983667 0.70114403]
#  [0.98933297 0.83983667 0.70114403]
#  ...
#  [0.46452599 0.50657566 0.56771066]
#  [0.9832654  0.50657566 0.56771066]
#  [0.84776494 0.50657566 0.56771066]]
# epoch:  53  loss:  nan
# [[0.33149468 0.2473676  0.90582071]
#  [0.7219052  0.2473676  0.90582071]
#  [0.66163027 0.2473676  0.90582071]
#  ...
#  [0.90318235 0.0758002  0.74282596]
#  [0.63818794 0.0758002  0.74282596]
#  [0.53508632 0.0758002  0.74282596]]
# epoch:  54  loss:  nan
# [[0.71694225 0.4113185  0.86125166]
#  [0.49164586 0.4113185  0.86125166]
#  [0.91538358 0.4113185  0.86125166]
#  ...
#  [0.89638386 0.26967431 0.22092467]
#  [0.88481958 0.26967431 0.22092467]
#  [0.69100471 0.26967431 0.22092467]]
# epoch:  55  loss:  nan
# [[0.94066581 0.41397908 0.29782175]
#  [0.89818276 0.41397908 0.29782175]
#  [0.58024729 0.41397908 0.29782175]
#  ...
#  [0.78814167 0.7747733  0.19389327]
#  [0.93189659 0.7747733  0.19389327]
#  [0.96477261 0.7747733  0.19389327]]
# epoch:  56  loss:  nan
# [[0.98140907 0.84237132 0.29091613]
#  [0.98335008 0.84237132 0.29091613]
#  [0.76096857 0.84237132 0.29091613]
#  ...
#  [0.76043832 0.25614339 0.72697246]
#  [0.39942941 0.25614339 0.72697246]
#  [0.75952205 0.25614339 0.72697246]]
# epoch:  57  loss:  nan
# [[0.87180643 0.75711573 0.44425179]
#  [0.93796167 0.75711573 0.44425179]
#  [0.89013248 0.75711573 0.44425179]
#  ...
#  [0.94640387 0.57216007 0.02385083]
#  [0.95209868 0.57216007 0.02385083]
#  [0.95287505 0.57216007 0.02385083]]
# epoch:  58  loss:  nan
# [[0.87618055 0.82415773 0.2330297 ]
#  [0.99040182 0.82415773 0.2330297 ]
#  [0.92414319 0.82415773 0.2330297 ]
#  ...
#  [0.9533369  0.62249402 0.32251599]
#  [0.98938203 0.62249402 0.32251599]
#  [0.90625252 0.62249402 0.32251599]]
# epoch:  59  loss:  nan
# [[0.94959905 0.51859532 0.79044089]
#  [0.70029424 0.51859532 0.79044089]
#  [0.9058792  0.51859532 0.79044089]
#  ...
#  [0.83412135 0.042899   0.03971078]
#  [0.83971942 0.042899   0.03971078]
#  [0.85654305 0.042899   0.03971078]]
# epoch:  60  loss:  nan
# [[-1.22815236e+06  8.01395575e-01 -1.17613497e-02]
#  [-1.22815242e+06  8.01395575e-01 -1.17613497e-02]
#  [-1.22815249e+06  8.01395575e-01 -1.17613497e-02]
#  ...
#  [ 6.22449930e-01  8.35455704e-01  7.98757877e-01]
#  [ 9.25596295e-01  8.35455704e-01  7.98757877e-01]
#  [ 8.26232527e-01  8.35455704e-01  7.98757877e-01]]
# epoch:  61  loss:  nan
# [[ 0.89457154  0.27400185 -0.05417292]
#  [ 0.89724887  0.27400185 -0.05417292]
#  [ 0.89561223  0.27400185 -0.05417292]
#  ...
#  [ 0.86520933  0.56635783  0.62931212]
#  [ 0.9784715   0.56635783  0.62931212]
#  [ 0.59070372  0.56635783  0.62931212]]
# epoch:  62  loss:  nan
# [[0.65804347 0.13616125 0.45691315]
#  [0.76034722 0.13616125 0.45691315]
#  [0.61861275 0.13616125 0.45691315]
#  ...
#  [0.79572197 0.59331867 0.59771917]
#  [0.86404247 0.59331867 0.59771917]
#  [0.62905762 0.59331867 0.59771917]]
# epoch:  63  loss:  nan
# [[0.96948538 0.41998339 0.79620649]
#  [0.646051   0.41998339 0.79620649]
#  [0.90133115 0.41998339 0.79620649]
#  ...
#  [0.7647043  0.54502119 0.6786057 ]
#  [0.92120047 0.54502119 0.6786057 ]
#  [0.88299519 0.54502119 0.6786057 ]]
# epoch:  64  loss:  nan
# [[0.94650117 0.83953415 0.9145853 ]
#  [0.7927969  0.83953415 0.9145853 ]
#  [0.69385532 0.83953415 0.9145853 ]
#  ...
#  [0.98149303 0.98136108 0.10421825]
#  [0.98977294 0.98136108 0.10421825]
#  [0.98726156 0.98136108 0.10421825]]
# epoch:  65  loss:  nan
# [[ 4.24762954e-01  2.72090656e-01  1.00043196e+00]
#  [ 5.74629357e-01  2.72090656e-01  1.00043196e+00]
#  [ 9.31856766e-01  2.72090656e-01  1.00043196e+00]
#  ...
#  [-6.48346110e+01  8.14315437e-01 -1.80014075e-03]
#  [-6.47668709e+01  8.14315437e-01 -1.80014075e-03]
#  [-6.47839395e+01  8.14315437e-01 -1.80014075e-03]]
# epoch:  66  loss:  nan
# [[0.71879303 0.66877791 0.81398936]
#  [0.60627073 0.66877791 0.81398936]
#  [0.86301061 0.66877791 0.81398936]
#  ...
#  [0.39787215 0.18208561 0.63284635]
#  [0.68077081 0.18208561 0.63284635]
#  [0.89201362 0.18208561 0.63284635]]
# epoch:  67  loss:  nan
# [[0.93399643 0.85000589 0.86849393]
#  [0.90832107 0.85000589 0.86849393]
#  [0.90408248 0.85000589 0.86849393]
#  ...
#  [0.19873884 0.02345968 0.90487897]
#  [0.50138371 0.02345968 0.90487897]
#  [0.81283924 0.02345968 0.90487897]]
# epoch:  68  loss:  nan
# [[ 1.1090024   0.82716207 -0.06151055]
#  [ 1.11408424  0.82716207 -0.06151055]
#  [ 1.11162106  0.82716207 -0.06151055]
#  ...
#  [ 0.74163644  0.40865149  0.72326636]
#  [ 0.67076809  0.40865149  0.72326636]
#  [ 0.88687088  0.40865149  0.72326636]]
# epoch:  69  loss:  nan
# [[ 0.94997639  0.37656657 -0.01600167]
#  [ 0.94611208  0.37656657 -0.01600167]
#  [ 0.93194724  0.37656657 -0.01600167]
#  ...
#  [ 0.90165827  0.44440963  0.20262583]
#  [ 0.82705009  0.44440963  0.20262583]
#  [ 0.95548164  0.44440963  0.20262583]]
# epoch:  70  loss:  nan
# [[0.93323279 0.64020998 0.25470288]
#  [0.76297298 0.64020998 0.25470288]
#  [0.91906315 0.64020998 0.25470288]
#  ...
#  [0.98342461 0.58947611 0.08366949]
#  [0.92074398 0.58947611 0.08366949]
#  [0.96556173 0.58947611 0.08366949]]
# epoch:  71  loss:  nan
# [[0.78627491 0.57560017 0.73996536]
#  [0.4163782  0.57560017 0.73996536]
#  [0.61219515 0.57560017 0.73996536]
#  ...
#  [0.96578083 0.95733049 0.30395077]
#  [0.95297704 0.95733049 0.30395077]
#  [0.86279985 0.95733049 0.30395077]]
# epoch:  72  loss:  nan
# [[0.95488358 0.98312211 0.23590226]
#  [0.98593933 0.98312211 0.23590226]
#  [0.94428879 0.98312211 0.23590226]
#  ...
#  [0.95051602 0.67955969 0.0900199 ]
#  [0.95100024 0.67955969 0.0900199 ]
#  [0.94177309 0.67955969 0.0900199 ]]
# epoch:  73  loss:  nan
# [[0.54423397 0.15529324 0.75403374]
#  [0.97874348 0.15529324 0.75403374]
#  [0.88657407 0.15529324 0.75403374]
#  ...
#  [0.81964772 0.82267913 0.69370838]
#  [0.76690009 0.82267913 0.69370838]
#  [0.8972106  0.82267913 0.69370838]]
# epoch:  74  loss:  nan
# [[       -inf  0.9765278  -0.04198687]
#  [       -inf  0.9765278  -0.04198687]
#  [       -inf  0.9765278  -0.04198687]
#  ...
#  [ 0.72195858  0.64091931  0.31137531]
#  [ 0.98824171  0.64091931  0.31137531]
#  [ 0.88410021  0.64091931  0.31137531]]
# epoch:  75  loss:  nan
# [[0.92952119 0.23475152 0.4907582 ]
#  [0.93139263 0.23475152 0.4907582 ]
#  [0.83765395 0.23475152 0.4907582 ]
#  ...
#  [0.98692267 0.54555132 0.36606517]
#  [0.9803693  0.54555132 0.36606517]
#  [0.87783184 0.54555132 0.36606517]]
# epoch:  76  loss:  nan
# [[0.64269304 0.24716781 0.68753975]
#  [0.78588246 0.24716781 0.68753975]
#  [0.9603713  0.24716781 0.68753975]
#  ...
#  [0.76353136 0.16451918 0.86625969]
#  [0.57134238 0.16451918 0.86625969]
#  [0.60301275 0.16451918 0.86625969]]
# epoch:  77  loss:  nan
# [[0.90480441 0.49849978 1.02641656]
#  [0.80645036 0.49849978 1.02641656]
#  [0.38910416 0.49849978 1.02641656]
#  ...
#  [0.41254054 0.63044465 0.66578895]
#  [0.72990362 0.63044465 0.66578895]
#  [0.55045014 0.63044465 0.66578895]]
# epoch:  78  loss:  nan
# [[0.95805167 0.28949769 0.55899648]
#  [0.72822683 0.28949769 0.55899648]
#  [0.93201728 0.28949769 0.55899648]
#  ...
#  [0.91031234 0.92121227 0.52228867]
#  [0.97595246 0.92121227 0.52228867]
#  [0.95921243 0.92121227 0.52228867]]
# epoch:  79  loss:  nan
# [[0.94297167 0.1697247  0.18219493]
#  [0.93450479 0.1697247  0.18219493]
#  [0.97224554 0.1697247  0.18219493]
#  ...
#  [0.97773891 0.62630504 0.33354497]
#  [0.74050673 0.62630504 0.33354497]
#  [0.94742398 0.62630504 0.33354497]]
# epoch:  80  loss:  nan
# [[0.95276877 0.85763907 0.1310301 ]
#  [0.97444366 0.85763907 0.1310301 ]
#  [0.96850564 0.85763907 0.1310301 ]
#  ...
#  [0.98314148 0.9497443  0.07291734]
#  [0.98843976 0.9497443  0.07291734]
#  [0.99202659 0.9497443  0.07291734]]
# epoch:  81  loss:  nan
# [[0.7941602  0.65257341 0.56098154]
#  [0.85507161 0.65257341 0.56098154]
#  [0.92679994 0.65257341 0.56098154]
#  ...
#  [0.98004672 0.55574596 0.25576858]
#  [0.95672956 0.55574596 0.25576858]
#  [0.96106321 0.55574596 0.25576858]]
# epoch:  82  loss:  nan
# [[0.99298614 0.97014355 0.0525899 ]
#  [0.98174406 0.97014355 0.0525899 ]
#  [0.9920407  0.97014355 0.0525899 ]
#  ...
#  [0.94331961 0.51944121 0.62754325]
#  [0.88083989 0.51944121 0.62754325]
#  [0.7713949  0.51944121 0.62754325]]
# epoch:  83  loss:  nan
# [[0.96870758 0.79830675 0.54628082]
#  [0.8709068  0.79830675 0.54628082]
#  [0.94758216 0.79830675 0.54628082]
#  ...
#  [0.83412838 0.07347546 0.15191673]
#  [0.94065166 0.07347546 0.15191673]
#  [0.60601122 0.07347546 0.15191673]]
# epoch:  84  loss:  nan
# [[0.85640958 0.02532466 0.83618153]
#  [0.83087982 0.02532466 0.83618153]
#  [0.65621162 0.02532466 0.83618153]
#  ...
#  [0.77744338 0.83678765 0.83466018]
#  [0.88080581 0.83678765 0.83466018]
#  [0.89769064 0.83678765 0.83466018]]
# epoch:  85  loss:  nan
# [[0.83308477 0.26366257 0.1586509 ]
#  [0.71372551 0.26366257 0.1586509 ]
#  [0.89051138 0.26366257 0.1586509 ]
#  ...
#  [0.97306021 0.92337263 0.28126629]
#  [0.866213   0.92337263 0.28126629]
#  [0.98724231 0.92337263 0.28126629]]
# epoch:  86  loss:  nan
# [[0.90115292 0.38748567 0.33333449]
#  [0.76895215 0.38748567 0.33333449]
#  [0.93742861 0.38748567 0.33333449]
#  ...
#  [0.70331275 0.47096078 0.35959594]
#  [0.89517569 0.47096078 0.35959594]
#  [0.8095643  0.47096078 0.35959594]]
# epoch:  87  loss:  nan
# [[ 0.59405787  0.57792618  0.86985578]
#  [ 0.81664752  0.57792618  0.86985578]
#  [ 0.50068343  0.57792618  0.86985578]
#  ...
#  [ 0.93183794  0.3567015  -0.02083929]
#  [ 0.8967951   0.3567015  -0.02083929]
#  [ 0.93546585  0.3567015  -0.02083929]]
# epoch:  88  loss:  nan
# [[0.70259148 0.33413455 0.19586607]
#  [0.98924339 0.33413455 0.19586607]
#  [0.9020592  0.33413455 0.19586607]
#  ...
#  [0.96025738 0.25613413 0.80940571]
#  [0.91387529 0.25613413 0.80940571]
#  [0.9694553  0.25613413 0.80940571]]
# epoch:  89  loss:  nan
# [[ 0.831056    0.11475707 -0.03384424]
#  [ 0.81501021  0.11475707 -0.03384424]
#  [ 0.84146894  0.11475707 -0.03384424]
#  ...
#  [ 0.85357928  0.95424523  0.8707702 ]
#  [ 0.80919049  0.95424523  0.8707702 ]
#  [ 0.90334069  0.95424523  0.8707702 ]]
# epoch:  90  loss:  nan
# [[0.69495858 0.38098448 0.97852021]
#  [0.42628311 0.38098448 0.97852021]
#  [0.73583967 0.38098448 0.97852021]
#  ...
#  [0.8249965  0.76990852 0.76051745]
#  [0.3766555  0.76990852 0.76051745]
#  [0.76719056 0.76990852 0.76051745]]
# epoch:  91  loss:  nan
# [[ 0.92497309  0.41567569  0.31182203]
#  [ 0.98928676  0.41567569  0.31182203]
#  [ 0.88572411  0.41567569  0.31182203]
#  ...
#  [ 0.83326392  0.13494083 -0.00497312]
#  [ 0.83250763  0.13494083 -0.00497312]
#  [ 0.84077692  0.13494083 -0.00497312]]
# epoch:  92  loss:  nan
# [[0.56844231 0.20085263 0.47780205]
#  [0.62764727 0.20085263 0.47780205]
#  [0.83148545 0.20085263 0.47780205]
#  ...
#  [0.9417332  0.30878461 0.26057023]
#  [0.82212941 0.30878461 0.26057023]
#  [0.9156509  0.30878461 0.26057023]]
# epoch:  93  loss:  nan
# [[0.66720402 0.85581717 0.44987629]
#  [0.94497959 0.85581717 0.44987629]
#  [0.98356812 0.85581717 0.44987629]
#  ...
#  [0.72179356 0.87317721 0.65730127]
#  [0.96641882 0.87317721 0.65730127]
#  [0.97542765 0.87317721 0.65730127]]
# epoch:  94  loss:  nan
# [[0.98944329 0.80175323 0.52947328]
#  [0.78441953 0.80175323 0.52947328]
#  [0.84997699 0.80175323 0.52947328]
#  ...
#  [0.97707343 0.80325711 0.35798296]
#  [0.97088538 0.80325711 0.35798296]
#  [0.95306163 0.80325711 0.35798296]]
# epoch:  95  loss:  nan
# [[0.61261951 0.23082239 0.68258768]
#  [0.44774005 0.23082239 0.68258768]
#  [0.95075925 0.23082239 0.68258768]
#  ...
#  [0.72199993 0.69674438 0.33684006]
#  [0.92189222 0.69674438 0.33684006]
#  [0.95214826 0.69674438 0.33684006]]
# epoch:  96  loss:  nan
# [[0.78005477 0.51479051 0.49148476]
#  [0.8032893  0.51479051 0.49148476]
#  [0.87704844 0.51479051 0.49148476]
#  ...
#  [0.97232102 0.59547589 0.21724901]
#  [0.72282615 0.59547589 0.21724901]
#  [0.90560494 0.59547589 0.21724901]]
# epoch:  97  loss:  nan
# [[ 0.95779192  0.43251989 -0.03934524]
#  [ 0.96414589  0.43251989 -0.03934524]
#  [ 0.96315116  0.43251989 -0.03934524]
#  ...
#  [ 0.70726023  0.68835175  0.89091136]
#  [ 0.93681822  0.68835175  0.89091136]
#  [ 0.5754496   0.68835175  0.89091136]]
# epoch:  98  loss:  nan
# [[0.85582461 0.86438674 0.75037855]
#  [0.76965741 0.86438674 0.75037855]
#  [0.79657381 0.86438674 0.75037855]
#  ...
#  [0.69897212 0.19381705 0.35946985]
#  [0.65713264 0.19381705 0.35946985]
#  [0.54331773 0.19381705 0.35946985]]
# epoch:  99  loss:  nan
# [[0.94989134 0.80730727 0.30597822]
#  [0.96960033 0.80730727 0.30597822]
#  [0.98857463 0.80730727 0.30597822]
#  ...
#  [0.88057047 0.25306782 0.10728996]
#  [0.92035369 0.25306782 0.10728996]
#  [0.83365586 0.25306782 0.10728996]]
# epoch:  100  loss:  nan
# /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/site-packages/numpy/lib/histograms.py:883: RuntimeWarning: invalid value encountered in divide
#   return n/db/n.sum(), bin_edges
# [[0.75172519 0.04130529 0.91633157]
#  [0.57225132 0.04130529 0.91633157]
#  [0.84133817 0.04130529 0.91633157]
#  ...
#  [0.94236489 0.84099138 0.18133961]
#  [0.94187959 0.84099138 0.18133961]
#  [0.89556488 0.84099138 0.18133961]]
# epoch:  101  loss:  nan
# [[ 0.91274104  0.34978405 -0.00460313]
#  [ 0.9082908   0.34978405 -0.00460313]
#  [ 0.91912306  0.34978405 -0.00460313]
#  ...
#  [ 0.93592836  0.51182458  0.77752776]
#  [ 0.84606219  0.51182458  0.77752776]
#  [ 0.49071079  0.51182458  0.77752776]]
# epoch:  102  loss:  nan
# [[0.98412634 0.32149796 0.31905996]
#  [0.77942429 0.32149796 0.31905996]
#  [0.80248984 0.32149796 0.31905996]
#  ...
#  [0.90716468 0.30893555 0.08305642]
#  [0.80546287 0.30893555 0.08305642]
#  [0.88046563 0.30893555 0.08305642]]
# epoch:  103  loss:  nan
# [[0.81050487 0.27196003 0.17126397]
#  [0.81832115 0.27196003 0.17126397]
#  [0.80371949 0.27196003 0.17126397]
#  ...
#  [0.98712718 0.40924062 0.79711341]
#  [0.78757336 0.40924062 0.79711341]
#  [0.12080735 0.40924062 0.79711341]]
# epoch:  104  loss:  nan
# [[       -inf  0.94450711 -0.00354789]
#  [       -inf  0.94450711 -0.00354789]
#  [       -inf  0.94450711 -0.00354789]
#  ...
#  [ 0.95578104  0.84492578  0.12033099]
#  [ 0.97638754  0.84492578  0.12033099]
#  [ 0.96846464  0.84492578  0.12033099]]
# epoch:  105  loss:  nan
# [[0.95616112 0.59617245 0.6039394 ]
#  [0.8698833  0.59617245 0.6039394 ]
#  [0.83312056 0.59617245 0.6039394 ]
#  ...
#  [0.84434889 0.62498849 0.71955943]
#  [0.97913551 0.62498849 0.71955943]
#  [0.87194258 0.62498849 0.71955943]]
# epoch:  106  loss:  nan
# [[ 9.53978027e-01  2.04971373e-01  2.82941727e-01]
#  [ 8.88179040e-01  2.04971373e-01  2.82941727e-01]
#  [ 7.54919301e-01  2.04971373e-01  2.82941727e-01]
#  ...
#  [-2.18688954e+04  7.38067937e-01 -2.47493561e-02]
#  [-2.18689173e+04  7.38067937e-01 -2.47493561e-02]
#  [-2.18689408e+04  7.38067937e-01 -2.47493561e-02]]
# epoch:  107  loss:  nan
# [[0.55848482 0.00556561 0.23987686]
#  [0.86196105 0.00556561 0.23987686]
#  [0.7983238  0.00556561 0.23987686]
#  ...
#  [0.96212611 0.42635038 0.24574535]
#  [0.97455188 0.42635038 0.24574535]
#  [0.89684613 0.42635038 0.24574535]]
# epoch:  108  loss:  nan
# [[0.63098626 0.41340585 0.623613  ]
#  [0.96837537 0.41340585 0.623613  ]
#  [0.76075258 0.41340585 0.623613  ]
#  ...
#  [0.88351786 0.62847568 0.4980417 ]
#  [0.63151525 0.62847568 0.4980417 ]
#  [0.83969664 0.62847568 0.4980417 ]]
# epoch:  109  loss:  nan
# [[ 0.41845092  0.01462644  0.63789304]
#  [ 0.69706035  0.01462644  0.63789304]
#  [ 0.89120742  0.01462644  0.63789304]
#  ...
#  [ 0.8343772   0.10931059 -0.04148154]
#  [ 0.83277055  0.10931059 -0.04148154]
#  [ 0.83978022  0.10931059 -0.04148154]]
# epoch:  110  loss:  nan
# [[0.96341696 0.92526987 0.67563805]
#  [0.91446466 0.92526987 0.67563805]
#  [0.69424168 0.92526987 0.67563805]
#  ...
#  [0.83628578 0.80273756 0.98717215]
#  [0.96398752 0.80273756 0.98717215]
#  [0.94957135 0.80273756 0.98717215]]
# epoch:  111  loss:  nan
# [[0.54617309 0.03847767 0.50725184]
#  [0.58075965 0.03847767 0.50725184]
#  [0.74202335 0.03847767 0.50725184]
#  ...
#  [0.86703908 0.89309691 0.19842313]
#  [0.93108261 0.89309691 0.19842313]
#  [0.98042895 0.89309691 0.19842313]]
# epoch:  112  loss:  nan
# [[ 0.90537253  0.29742256 -0.05661822]
#  [ 0.90894684  0.29742256 -0.05661822]
#  [ 0.90677832  0.29742256 -0.05661822]
#  ...
#  [ 0.5724273   0.62965375  0.52121312]
#  [ 0.97784003  0.62965375  0.52121312]
#  [ 0.65240973  0.62965375  0.52121312]]
# epoch:  113  loss:  nan
# [[0.55848086 0.70696976 0.84810699]
#  [0.90318755 0.70696976 0.84810699]
#  [0.89507169 0.70696976 0.84810699]
#  ...
#  [0.95340836 0.52844248 0.05429222]
#  [0.95531338 0.52844248 0.05429222]
#  [0.93329536 0.52844248 0.05429222]]
# epoch:  114  loss:  nan
# [[0.75223273 0.41394454 0.68610571]
#  [0.93149711 0.41394454 0.68610571]
#  [0.59601207 0.41394454 0.68610571]
#  ...
#  [0.57787248 0.5611871  0.73524909]
#  [0.77213549 0.5611871  0.73524909]
#  [0.89186538 0.5611871  0.73524909]]
# epoch:  115  loss:  nan
# [[0.77566319 0.496862   0.44442606]
#  [0.76857203 0.496862   0.44442606]
#  [0.71522905 0.496862   0.44442606]
#  ...
#  [0.99059455 0.32544673 0.59123353]
#  [0.7015333  0.32544673 0.59123353]
#  [0.68480652 0.32544673 0.59123353]]
# epoch:  116  loss:  nan
# [[0.81235296 0.3414407  0.73366388]
#  [0.8962602  0.3414407  0.73366388]
#  [0.81160656 0.3414407  0.73366388]
#  ...
#  [0.93123634 0.68703654 0.31324465]
#  [0.94823614 0.68703654 0.31324465]
#  [0.91165773 0.68703654 0.31324465]]
# epoch:  117  loss:  nan
# [[0.72232408 0.0395959  0.72281791]
#  [0.7261016  0.0395959  0.72281791]
#  [0.25172021 0.0395959  0.72281791]
#  ...
#  [0.86931223 0.09249759 0.27662155]
#  [0.87192124 0.09249759 0.27662155]
#  [0.79501511 0.09249759 0.27662155]]
# epoch:  118  loss:  nan
# [[0.90733328 0.4505477  0.08382459]
#  [0.97804357 0.4505477  0.08382459]
#  [0.93763912 0.4505477  0.08382459]
#  ...
#  [0.89022296 0.84620226 0.66475752]
#  [0.91508119 0.84620226 0.66475752]
#  [0.79954937 0.84620226 0.66475752]]
# epoch:  119  loss:  nan
# [[0.92532212 0.18785158 0.13923052]
#  [0.83020793 0.18785158 0.13923052]
#  [0.90424206 0.18785158 0.13923052]
#  ...
#  [0.71860752 0.20166125 0.50333719]
#  [0.88978458 0.20166125 0.50333719]
#  [0.73331187 0.20166125 0.50333719]]
# epoch:  120  loss:  nan
# [[0.59634014 0.26093334 0.58884348]
#  [0.6519396  0.26093334 0.58884348]
#  [0.48271131 0.26093334 0.58884348]
#  ...
#  [0.79107661 0.03045275 0.02180851]
#  [0.85446287 0.03045275 0.02180851]
#  [0.75355958 0.03045275 0.02180851]]
# epoch:  121  loss:  nan
# [[0.86766369 0.28179288 0.90251302]
#  [0.80308577 0.28179288 0.90251302]
#  [0.53918626 0.28179288 0.90251302]
#  ...
#  [0.81903308 0.40188403 0.67052438]
#  [0.96951198 0.40188403 0.67052438]
#  [0.90618249 0.40188403 0.67052438]]
# epoch:  122  loss:  nan
# [[0.94299748 0.31463088 0.27744788]
#  [0.67474033 0.31463088 0.27744788]
#  [0.95041131 0.31463088 0.27744788]
#  ...
#  [0.95311646 0.92666041 0.38012949]
#  [0.77318405 0.92666041 0.38012949]
#  [0.86722861 0.92666041 0.38012949]]
# epoch:  123  loss:  nan
# [[0.98252404 0.72436731 0.59520248]
#  [0.82183315 0.72436731 0.59520248]
#  [0.83454111 0.72436731 0.59520248]
#  ...
#  [0.89555476 0.24974188 0.06150366]
#  [0.82140009 0.24974188 0.06150366]
#  [0.90588082 0.24974188 0.06150366]]
# epoch:  124  loss:  nan
# [[0.57028521 0.9011692  0.81047806]
#  [0.93807486 0.9011692  0.81047806]
#  [0.60264778 0.9011692  0.81047806]
#  ...
#  [0.82501133 0.68492516 0.8455633 ]
#  [0.92409188 0.68492516 0.8455633 ]
#  [0.75856618 0.68492516 0.8455633 ]]
# epoch:  125  loss:  nan
# [[ 9.07373072e-01  6.70854617e-01  9.42630457e-01]
#  [ 7.05301664e-02  6.70854617e-01  9.42630457e-01]
#  [ 8.87281254e-01  6.70854617e-01  9.42630457e-01]
#  ...
#  [-7.06610665e+02  7.77943494e-01 -1.24448085e-02]
#  [-7.06730559e+02  7.77943494e-01 -1.24448085e-02]
#  [-7.06577872e+02  7.77943494e-01 -1.24448085e-02]]
# epoch:  126  loss:  nan
# [[0.69055801 0.08238384 0.35540103]
#  [0.93642085 0.08238384 0.35540103]
#  [0.73535273 0.08238384 0.35540103]
#  ...
#  [0.9837702  0.41133045 0.0313341 ]
#  [0.90697341 0.41133045 0.0313341 ]
#  [0.88544484 0.41133045 0.0313341 ]]
# epoch:  127  loss:  nan
# [[0.98894213 0.7950804  0.01982422]
#  [0.99019599 0.7950804  0.01982422]
#  [0.98063979 0.7950804  0.01982422]
#  ...
#  [0.81726394 0.23277874 0.82208709]
#  [0.75475678 0.23277874 0.82208709]
#  [0.92197275 0.23277874 0.82208709]]
# epoch:  128  loss:  nan
# [[0.95090507 0.65089274 1.00852446]
#  [0.53366972 0.65089274 1.00852446]
#  [0.39264644 0.65089274 1.00852446]
#  ...
#  [0.84437697 0.51554719 0.48881475]
#  [0.70630694 0.51554719 0.48881475]
#  [0.88183746 0.51554719 0.48881475]]
# epoch:  129  loss:  nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 14>()
#      39 samps=s.sample(rng,(5,10))
#      41 permute_rng, rng = random.split(rng)
# ---> 45 theta = np.column_stack((np.repeat(mu,5).T.reshape(50,1),np.repeat(sigma_int,50).reshape(50,1)))
#      49 X_ = np.column_stack((samps.T.reshape(50,1),theta))
#      51 X = np.append(X,X_,axis=0)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:2626, in repeat(a, repeats, axis, total_repeat_length)
#    2624   result_shape: List[DimSize] = list(input_shape)
#    2625   result_shape[axis] *= repeats
# -> 2626   return reshape(a, result_shape)
#    2628 repeats = np.ravel(repeats)
#    2629 if ndim(a) != 0:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/site-packages/jax/_src/numpy/lax_numpy.py:772, in reshape(a, newshape, order)
#     769 util.check_arraylike("reshape", a)
#     770 try:
#     771   # forward to method for ndarrays
# --> 772   return a.reshape(newshape, order=order)  # type: ignore[call-overload,union-attr]
#     773 except AttributeError:
#     774   return asarray(a).reshape(newshape, order=order)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:143, in _reshape(a, order, *args)
#     138 def _reshape(a: Array, *args: Any, order: str = "C") -> Array:
#     139   """Returns an array containing the same data with a new shape.
#     140
#     141   Refer to :func:`jax.numpy.reshape` for full documentation.
#     142   """
# --> 143   newshape = _compute_newshape(a, args[0] if len(args) == 1 else args)
#     144   if order == "C":
#     145     return lax.reshape(a, newshape, None)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:133, in _compute_newshape(a, newshape)
#     131   if sz is not None:
#     132     return (*newshape[:i], sz, *newshape[i+1:])
# --> 133 return tuple(-core.divide_shape_sizes(np.shape(a), newshape)
#     134              if core.symbolic_equal_dim(d, -1) else d
#     135              for d in newshape)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/site-packages/jax/_src/numpy/array_methods.py:134, in <genexpr>(.0)
#     131   if sz is not None:
#     132     return (*newshape[:i], sz, *newshape[i+1:])
#     133 return tuple(-core.divide_shape_sizes(np.shape(a), newshape)
# --> 134              if core.symbolic_equal_dim(d, -1) else d
#     135              for d in newshape)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/site-packages/jax/_src/core.py:1928, in symbolic_equal_dim(d1, d2)
#    1927 def symbolic_equal_dim(d1: DimSize, d2: DimSize) -> bool:
# -> 1928   if d1 is d2 or same_referent(d1, d2): return True
#    1929   handler, ds = _dim_handler_and_canonical(d1, d2)
#    1930   return handler.symbolic_equal(*ds)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/site-packages/jax/_src/core.py:1210, in same_referent(x, y)
#    1209 def same_referent(x: Any, y: Any) -> bool:
# -> 1210   return get_referent(x) is get_referent(y)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/site-packages/jax/_src/core.py:1207, in get_referent(x)
#    1206 def get_referent(x: Any) -> Any:
# -> 1207   return x.get_referent() if isinstance(x, Tracer) else x
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_env/lib/python3.10/abc.py:119, in ABCMeta.__instancecheck__(cls, instance)
#     117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
# --> 119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
for i in range(X.shape[0]):
    print(X[i,:])

# %%
rng, flow_rng = random.split(random.PRNGKey(0))


def minmax_unscale(X,min,max):
  return X * (max - min) + min




no_samps = 100000

samp=sample(rng, params,minmax_scale(np.repeat(np.array([21.1]),no_samps).reshape(no_samps,1),min[1:],max[1:]),no_samps)

print(samp)

samp = minmax_unscale(samp[:,0],min[0],max[0])

# %%
print(samp.shape)
print(min)
print(max[1:])

# %%
from matplotlib import pyplot as plt
plt.hist(samp,bins=100)
plt.show()

# %%
from matplotlib import pyplot as plt
c=['red','green','blue','yellow','pink']
mm = np.array([20.7,20.8,20.9,21,21.1])
bins=np.linspace(20.3,21.1,100)
no_samps = 100000


plt.figure(figsize=(12,6))



for i,m in enumerate(mm):
    
    print(minmax_scale(np.repeat(np.array([m]),no_samps).reshape(no_samps,1),min[1:],max[1:]))
    samp=sample(rng, params,minmax_scale(np.repeat(np.array([m]),no_samps).reshape(no_samps,1),min[1:],max[1:]),no_samps)
    samp = minmax_unscale(samp[:,0],min[0],max[0])

    plt.hist(samp,density=True,bins=bins,color=c[i],histtype='step',label='$m_0=$'+str(m)+',$\sigma_{int}=$'+str(sigma_int)+',$m_{cut}=$'+str(mu_cut)+',$\sigma_{cut}=$'+str(sigma_cut))
    s=snp(np.array([m]),np.array([0.1]),21,0.01)
    plt.plot(bins,np.exp(s.log_prob(bins)),color=c[i])
    
    print(np.min(samp),np.max(samp))

    #plt.hist(s.sample(rng,(1000,1)).reshape(1000,),density=True,histtype='step')
    

plt.legend(loc='center left',frameon=False,fontsize=12)
plt.xlabel('$\hat{m}_s$',fontsize=11)
plt.ylabel('$p(\hat{m}_s|m_0,\sigma_{int},m_{cut},\sigma_{cut})$',fontsize=12)
plt.title('Normalising Flow',fontsize=12)

plt.show()

# %%
plt.hist(minmax_scale(samp,20,22),bins=minmax_scale(np.linspace(20,22,100),20,22))
plt.show()

# %%
a = np.arange(10)

print(np.repeat(a,10))

# %%
bins = np.linspace(2.75,3.25,100)

plt.hist(samp,density=True,bins=bins)

# %%
plt.hist(samp,bins=100)

# %%
bs=np.arange(10)

XX= np.column_stack((bs,bs))


print(np.repeat(bs.reshape(10,1),5,axis=1).reshape(50,))

# %%
print(X)

# %%
permute_rng, rng = random.split(rng)

s = snp(m_int=np.array([20.99]),sigma_int=0.1,m_cut=21,sigma_cut=0.01)
xxx=s.sample(rng,(10000,1)).reshape(10000,)
rr= np.linspace(np.min(xxx),np.max(xxx),100)
plt.plot(rr,np.exp(s.log_prob(rr)))
plt.hist(xxx,bins=100,density=True)
plt.show()

# %%
from matplotlib import pyplot as plt
sigma_int=0.1
sigma_cut=0.01
mu_cut= 21

permute_rng, rng = random.split(random.PRNGKey(0))


sigma_int=0.1
sigma_cut=0.01
mu_cut= 21

mu=random.uniform(rng,(10,)) + 20.5

permute_rng, rng = random.split(rng)


s = snp(m_int=mu,sigma_int=sigma_int,m_cut=mu_cut,sigma_cut=sigma_cut)



samps=s.sample(rng,(1000,10))




X = np.column_stack((samps.T.reshape(10000,),np.repeat(mu.reshape(10,1),1000,axis=1).reshape(10000,)))







for i in range(10):
  xxx=X[i*1000:(i+1)*1000,0]
  plt.hist(xxx,bins=100,density=True)
  s = snp(m_int=np.array([X[i*1000,1]]),sigma_int=0.1,m_cut=21,sigma_cut=0.01)
  rr= np.linspace(np.min(xxx),np.max(xxx),100)
  plt.plot(rr,np.exp(s.log_prob(rr)))
  plt.show()

# %%
print
